# %%
#name= ekta
# date = 19-02-2026
#  Store a message in a variable, and then print that message
message = "my first python asssignment"
print(message)
# Out:
# my first python asssignment

# %%
#name= ekta
# date = 19-02-2026
# change the value of your variable to a new message and print the new message
message = "my first python asssignment"
print(message)

message = "python asssignnment"
print (message)
# Out:
# my first python asssignment
# python asssignnment

# %%
name = "eric"
print (f"hello {name}, would you like to learn some python ")
# Out:
# hello eric, would you like to learn some python

# %%
print ('Albert Einstein once said, “A person who never made a mistake never tried anything new.”')
# Out:
# Albert Einstein once said, “A person who never made a mistake never tried anything new.”

# %%
famous_person = "Albert Einstein"
message = f'{famous_person} once said, “A person who never made a mistake never tried anything new.”'
print (message)
# Out:
# Albert Einstein once said, “A person who never made a mistake never tried anything new.”

# %%
print(5+3)
print(10-2)
print(4*2)
print(16/2)
# Out:
# 8
# 8
# 8
# 8.0

# %%
fav_num = 11
print(f'my fav no. is {fav_num}')
# Out:
# my fav no. is 11

# %%
name = ("ekta","bhavansh","pankaj","adi")
print(name[3])
print(name[1])
print(name[0])
print(name[2])
# Out:
# adi
# bhavansh
# ekta
# pankaj

# %%
name = ("ekta","bhavansh","pankaj","adi")
print(f'hey {name[3]},gud morning')
print(f'hey {name[1]},gud morning')
print(f'hey {name[0]},gud morning')
print(f'hey {name[2]},gud morning')
# Out:
# hey adi,gud morning
# hey bhavansh,gud morning
# hey ekta,gud morning
# hey pankaj,gud morning

# %%
transport= ("motorcycle ","car", "mercidize benz")
print(f'i would like to own a {transport[0]}.')
print(f'i would like to drive a {transport[1]}.')
print(f'i would like to buy a {transport[2]}.')
# Out:
# i would like to own a motorcycle .
# i would like to drive a car.
# i would like to buy a mercidize benz.
